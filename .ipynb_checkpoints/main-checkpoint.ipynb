# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key,
                    consumer_secret,
                    access_token,
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
news_users = ("@nytimes", "@cnn", "@BBCWorld", "@CBSNews", "@FoxNews")

# %%
user_results = []

counter = 0
oldest_tweet = None

# Loop through each user
for user in news_users:
    counter = 0
    oldest_tweet = None

    # Loop through 5 pages of tweets (total 200 tweets)
    for x in range(1, 6):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(user, page=x, max_id=oldest_tweet)

        # Loop through all tweets
        for tweet in public_tweets:

            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]
            tweet_text = tweet['text']
            
            # Add each value to the appropriate list
            date = tweet["created_at"]
            converted_time = datetime.strptime(date, "%a %b %d %H:%M:%S %z %Y")
        
        # Create a dictionaty of results
            user_results.append({
            "User": user,
            "Date": converted_time,
            "Tweet": tweet_text,
            "Compound Score": compound,
            "Positive Score": pos,
            "Neutral Score": neu,
            "Negative Score": neg,
            "Tweet Count": counter
                })
            counter += 1

# %%
df = pd.DataFrame(user_results)
df = df[["User",
         "Date",
         "Tweet Count",
         "Tweet",
         "Compound Score", 
         "Positive Score", 
         "Neutral Score", 
         "Negative Score"]]
df = df.sort_values("Tweet Count", ascending=False)
df.to_csv("newssentiment.csv")

# %%
df_nytimes = df[df["User"] == "@nytimes"]
df_cnn = df[df["User"] == "@cnn"]
df_bbcworld = df[df["User"] == "@BBCWorld"]
df_cbsnews = df[df["User"] == "@CBSNews"]
df_foxnews = df[df["User"] == "@FoxNews"]

# %%
df_cbsnews
# Out:
#          User                      Date  Tweet Count  \
# 399  @CBSNews 2018-08-01 06:48:05+00:00           99
# 398  @CBSNews 2018-08-01 07:03:03+00:00           98
# 397  @CBSNews 2018-08-01 07:18:04+00:00           97
# 396  @CBSNews 2018-08-01 07:33:04+00:00           96
# 395  @CBSNews 2018-08-01 07:48:03+00:00           95
# 394  @CBSNews 2018-08-01 08:03:03+00:00           94
# 393  @CBSNews 2018-08-01 08:18:03+00:00           93
# 392  @CBSNews 2018-08-01 08:33:03+00:00           92
# 391  @CBSNews 2018-08-01 08:48:03+00:00           91
# 390  @CBSNews 2018-08-01 08:54:06+00:00           90
# 389  @CBSNews 2018-08-01 09:03:03+00:00           89
# 388  @CBSNews 2018-08-01 09:18:03+00:00           88
# 387  @CBSNews 2018-08-01 09:32:04+00:00           87
# 386  @CBSNews 2018-08-01 09:39:06+00:00           86
# 385  @CBSNews 2018-08-01 09:48:04+00:00           85
# 384  @CBSNews 2018-08-01 10:03:03+00:00           84
# 383  @CBSNews 2018-08-01 10:15:33+00:00           83
# 382  @CBSNews 2018-08-01 10:19:52+00:00           82
# 381  @CBSNews 2018-08-01 10:28:38+00:00           81
# 380  @CBSNews 2018-08-01 10:29:52+00:00           80
# 379  @CBSNews 2018-08-01 10:39:55+00:00           79
# 378  @CBSNews 2018-08-01 10:45:25+00:00           78
# 377  @CBSNews 2018-08-01 10:59:33+00:00           77
# 385  Young cancer patient goes viral with "In My Fe...         -0.6597
# 384  U.S. military boosts troop security after dead...          0.5719
# 383  A federal judge issued a temporary restraining...         -0.4404
# 382  Washington @Nationals set team scoring record ...         -0.4588
# 381  RT @CBSThisMorning: THIS MORNING: \n🔜@michaelj...         -0.4767
# 380  AHEAD on @CBSThisMorning: We'll talk to former...          0.0000
# 379  Korean War remains to head for Hawaii after re...         -0.5994
# 378  One day after actor @AlanAlda revealed his Par...          0.0000
# 377  Top Putin foe ramps up "Dossier" project to sp...         -0.2732
# 376  Aeroméxico Flight 2431 was carrying 99 passeng...          0.0000
# 375  President Trump says the time has come for vot...          0.0772
# 374  RT @CBSThisMorning: A federal judge is tempora...         -0.6124
# 373  RT @CBSThisMorning: "I believe that I am champ...          0.6908
# 372  "Traumatic" or "summer camp"? Officials offer ...          0.0000
# 371  RT @CBSThisMorning: "What I'm doing is legally...          0.6124
# 370  RT @CBSThisMorning: "There is nothing good tha...         -0.6711
# ..                                                 ...             ...
# 329  WATCH: This official in Connecticut kneeled du...          0.0000
# 328  Conspiracy theorist Alex Jones wants a Texas j...         -0.6486
# 327  Former President Barack Obama is jumping back ...          0.0000
# 326  The dirt on the ground is making climate chang...         -0.6705
# 325  Former waitress anonymously sends $1,000 and a...         -0.5423
# 324  Russian reporters working on investigation wit...         -0.8126
# 323  RT @CBSThisMorning: New video shows the terrif...         -0.7269
# 322  Harrisburg Diocese identifies 71 alleged sex a...         -0.7845
# 321  WATCH: Rescuers find dog that survived wildfir...          0.2732
# 320  Walmart, the nation's largest private employer...         -0.2263
# 319  Flights at a Paris airport were delayed Wednes...         -0.2263
# 318  A U.S. appeals court says President Trump's ex...         -0.5267
# 317  A caravan of "grannies" is traveling 2,000 mil...         -0.2500
# 316  Google reportedly plans a return to China's se...         -0.1531
# 315  Stunning new video shows an Aeromexico plane w...          0.3818
# 314  Houston police have identified the suspect in ...         -0.7845
# 313  President Trump called for Attorney General Je...          0.0000
# 312  Officials say the Carr Fire has destroyed more...         -0.8718
# 311  Penn. is investigating the sexual abuse by pri...         -0.2960
# 310  An ISIS group in central Asia says it killed a...         -0.6705
# 309  A 10-year-old named Clark Kent broke a swimmin...         -0.4215
# 308  French lawmakers approve fines for sex harassm...         -0.7964
# 307  WATCH NOW: Vice Pence speaks at ceremony in Ha...         -0.7351
# 306  "Some have called the Korean War the 'forgotte...          0.3716
# 305  RT @CBSEveningNews: Aeromexico crash survivor:...         -0.0516
# 304  "We see today as tangible progress in our atte...          0.4854
# 303  "We pledge to you that we will never stop stri...         -0.1808
# 302  WATCH: Remains of the fallen U.S. soldiers fro...         -0.7506
# 301  Medal known as "Nobel for mathematics" stolen ...          0.3818
# 300  Police ID suspect in killing of George H.W. Bu...         -0.7650
#
#      Positive Score  Neutral Score  Negative Score
# 399           0.000          0.864           0.136
# 398           0.000          1.000           0.000
# 397           0.000          0.492           0.508
# 396           0.079          0.424           0.497
# 395           0.000          1.000           0.000
# 394           0.000          1.000           0.000
# 393           0.000          1.000           0.000
# 392           0.000          1.000           0.000
# 391           0.000          0.807           0.193
# 390           0.000          0.738           0.262
# 389           0.000          1.000           0.000
# 388           0.167          0.833           0.000
# 387           0.000          0.738           0.262
# 386           0.144          0.749           0.107
# 385           0.000          0.732           0.268
# 384           0.343          0.657           0.000
# 383           0.000          0.868           0.132
# 382           0.000          0.850           0.150
# 381           0.000          0.807           0.193
# 380           0.000          1.000           0.000
# 379           0.000          0.738           0.262
# 378           0.000          1.000           0.000
# 377           0.115          0.701           0.185
# 376           0.000          1.000           0.000
# 375           0.058          0.942           0.000
# 374           0.000          0.762           0.238
# 373           0.231          0.769           0.000
# 372           0.000          1.000           0.000
# 371           0.200          0.800           0.000
# 370           0.059          0.706           0.235
# ..              ...            ...             ...
# 329           0.000          1.000           0.000
# 328           0.000          0.751           0.249
# 327           0.000          1.000           0.000
# 326           0.000          0.703           0.297
# 325           0.063          0.741           0.196
# 324           0.000          0.598           0.402
# 323           0.000          0.747           0.253
# 322           0.000          0.615           0.385
# 321           0.200          0.667           0.133
# 320           0.000          0.894           0.106
# 319           0.000          0.899           0.101
# 318           0.000          0.815           0.185
# 317           0.000          0.905           0.095
# 316           0.000          0.914           0.086
# 315           0.120          0.880           0.000
# 314           0.000          0.711           0.289
# 313           0.000          1.000           0.000
# 312           0.000          0.632           0.368
# 311           0.119          0.714           0.167
# 310           0.000          0.830           0.170
# 309           0.000          0.872           0.128
# 308           0.000          0.628           0.372
# 307           0.000          0.763           0.237
# 306           0.176          0.671           0.154
# 305           0.095          0.802           0.103
# 304           0.179          0.821           0.000
# 303           0.168          0.642           0.190
# 302           0.000          0.686           0.314
# 301           0.290          0.550           0.160
# 300           0.000          0.602           0.398
#
# [100 rows x 8 columns]

# %%
plt.scatter(df_nytimes["Tweet Count"], df_nytimes["Compound Score"], edgecolors="black")
plt.scatter(df_cbsnews["Tweet Count"], df_cbsnews["Compound Score"], edgecolors="black")
plt.scatter(df_cnn["Tweet Count"], df_cnn["Compound Score"], edgecolors="black")
plt.scatter(df_bbcworld["Tweet Count"], df_bbcworld["Compound Score"], edgecolors="black")
plt.scatter(df_foxnews["Tweet Count"], df_foxnews["Compound Score"], edgecolors="black")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.title("Sentiment Analysis of Media Tweets (07/31/2018)")
plt.legend(news_users, bbox_to_anchor =(1,1), title="Media Sources")
sns.set()
plt.savefig("tweetpolarityscatter.png", dpi=100)
plt.show()

# %%
average_group = df.groupby("User").mean()["Compound Score"]
averages = []

for x in average_group:
    averages.append(x)

# %%
colors = ["skyblue", "green", "red", "blue", "yellow"]
sns.set()
average_group.plot.bar(color=colors, align = "center", width=1, edgecolor = "black", )

plt.title("Overall Media Sentiment based on Twitter (07/31/2018)")
plt.xlabel("")
plt.xticks(np.arange(len(news_users)), ("BBC", "CBS", "CNN", "Fox", "NYT"), rotation=0)
plt.ylabel("Tweet Polarity")

count = 0
for x in averages:
    if x < 0:
        ybar = max(averages)*.10
    else:
        ybar = min(averages)*.10
    plt.text(count, ybar, round(x,2), ha="center")
    count += 1
    
plt.grid(None)
plt.savefig("tweetpolarity.png", dpi=100)

plt.show()
